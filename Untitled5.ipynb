# %% [markdown]
# <a href="https://colab.research.google.com/github/shailendra598/house-price-dashboard/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-0cfe4988-93ad-4d09-bb3a-3b3a4d6802dc" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0cfe4988-93ad-4d09-bb3a-3b3a4d6802dc">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

df = pd.read_csv("Cleaned_HR_Data_Analysis.csv")

df.head()
# Out:
#    Employee ID  StartDate                    Title BusinessUnit  \
# 0         3427  20-Sep-19  Production Technician I         CCDR
# 1         3428  11-Feb-23  Production Technician I           EW
# 2         3429  10-Dec-18       Area Sales Manager           PL
# 3         3430  21-Jun-21       Area Sales Manager         CCDR
# 4         3431  29-Jun-19       Area Sales Manager          TNS
#
#   EmployeeStatus EmployeeType PayZone EmployeeClassificationType  \
# 0         Active     Contract  Zone C                  Temporary
# 1         Active     Contract  Zone A                  Part-Time
# 2         Active    Full-Time  Zone B                  Part-Time
# 3         Active     Contract  Zone A                  Full-Time
# 4         Active     Contract  Zone A                  Temporary
#
#       DepartmentType              Division  ... Engagement Score  \
# 0  Production         Finance & Accounting  ...                1
# ...

# %%
df.shape
# Out:
# (2845, 28)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2845 entries, 0 to 2844
# Data columns (total 28 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Employee ID                 2845 non-null   int64
#  1   StartDate                   2845 non-null   object
#  2   Title                       2845 non-null   object
#  3   BusinessUnit                2845 non-null   object
#  4   EmployeeStatus              2845 non-null   object
#  5   EmployeeType                2845 non-null   object
#  6   PayZone                     2845 non-null   object
#  7   EmployeeClassificationType  2845 non-null   object
#  8   DepartmentType              2845 non-null   object
#  9   Division                    2845 non-null   object
#  10  DOB                         2845 non-null   object
#  11  State                       2845 non-null   object
#  12  GenderCode                  2845 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# Employee ID                   0
# StartDate                     0
# Title                         0
# BusinessUnit                  0
# EmployeeStatus                0
# EmployeeType                  0
# PayZone                       0
# EmployeeClassificationType    0
# DepartmentType                0
# Division                      0
# DOB                           0
# State                         0
# GenderCode                    0
# RaceDesc                      0
# MaritalDesc                   0
# Performance Score             0
# Current Employee Rating       0
# Survey Date                   0
# Engagement Score              0
# Satisfaction Score            0
# Work-Life Balance Score       0
# Training Date                 0
# Training Program Name         0
# Training Type                 0
# Training Outcome              0
# Training Duration(Days)       0
# Training Cost                 0
# Age                           0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop_duplicates(inplace=True)

df.fillna("Unknown", inplace=True)

# %%
df.to_csv("HR_Data_Cleaned_Final.csv", index=False)

files.download("HR_Data_Cleaned_Final.csv")

# %%
import pandas as pd

df = pd.read_csv("HR_Data_Cleaned_Final.csv")

df.head()
# Out:
#    Employee ID  StartDate                    Title BusinessUnit  \
# 0         3427  20-Sep-19  Production Technician I         CCDR
# 1         3428  11-Feb-23  Production Technician I           EW
# 2         3429  10-Dec-18       Area Sales Manager           PL
# 3         3430  21-Jun-21       Area Sales Manager         CCDR
# 4         3431  29-Jun-19       Area Sales Manager          TNS
#
#   EmployeeStatus EmployeeType PayZone EmployeeClassificationType  \
# 0         Active     Contract  Zone C                  Temporary
# 1         Active     Contract  Zone A                  Part-Time
# 2         Active    Full-Time  Zone B                  Part-Time
# 3         Active     Contract  Zone A                  Full-Time
# 4         Active     Contract  Zone A                  Temporary
#
#       DepartmentType              Division  ... Engagement Score  \
# 0  Production         Finance & Accounting  ...                1
# ...

# %%
df.shape
# Out:
# (2845, 28)

# %%
df.columns
# Out:
# Index(['Employee ID', 'StartDate', 'Title', 'BusinessUnit', 'EmployeeStatus',
#        'EmployeeType', 'PayZone', 'EmployeeClassificationType',
#        'DepartmentType', 'Division', 'DOB', 'State', 'GenderCode', 'RaceDesc',
#        'MaritalDesc', 'Performance Score', 'Current Employee Rating',
#        'Survey Date', 'Engagement Score', 'Satisfaction Score',
#        'Work-Life Balance Score', 'Training Date', 'Training Program Name',
#        'Training Type', 'Training Outcome', 'Training Duration(Days)',
#        'Training Cost', 'Age'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Employee ID                   0
# StartDate                     0
# Title                         0
# BusinessUnit                  0
# EmployeeStatus                0
# EmployeeType                  0
# PayZone                       0
# EmployeeClassificationType    0
# DepartmentType                0
# Division                      0
# DOB                           0
# State                         0
# GenderCode                    0
# RaceDesc                      0
# MaritalDesc                   0
# Performance Score             0
# Current Employee Rating       0
# Survey Date                   0
# Engagement Score              0
# Satisfaction Score            0
# Work-Life Balance Score       0
# Training Date                 0
# Training Program Name         0
# Training Type                 0
# Training Outcome              0
# Training Duration(Days)       0
# Training Cost                 0
# Age                           0
# dtype: int64

# %%
df.describe()
# Out:
#        Employee ID  Current Employee Rating  Engagement Score  \
# count  2845.000000              2845.000000       2845.000000
# mean   2470.591916                 2.974692          2.941652
# std     859.450107                 1.012610          1.435230
# min    1001.000000                 1.000000          1.000000
# 25%    1736.000000                 2.000000          2.000000
# 50%    2456.000000                 3.000000          3.000000
# 75%    3197.000000                 3.000000          4.000000
# max    4000.000000                 5.000000          5.000000
#
#        Satisfaction Score  Work-Life Balance Score  Training Duration(Days)  \
# count         2845.000000              2845.000000              2845.000000
# mean             3.028471                 2.989104                 2.973989
# std              1.410067                 1.408816                 1.419682
# min              1.000000                 1.000000                 1.000000
# ...

# %%
print(df.columns.tolist())
# Out:
# ['Employee ID', 'StartDate', 'Title', 'BusinessUnit', 'EmployeeStatus', 'EmployeeType', 'PayZone', 'EmployeeClassificationType', 'DepartmentType', 'Division', 'DOB', 'State', 'GenderCode', 'RaceDesc', 'MaritalDesc', 'Performance Score', 'Current Employee Rating', 'Survey Date', 'Engagement Score', 'Satisfaction Score', 'Work-Life Balance Score', 'Training Date', 'Training Program Name', 'Training Type', 'Training Outcome', 'Training Duration(Days)', 'Training Cost', 'Age']

# %%
for col in df.columns:
    print(col)
# Out:
# Employee ID
# StartDate
# Title
# BusinessUnit
# EmployeeStatus
# EmployeeType
# PayZone
# EmployeeClassificationType
# DepartmentType
# Division
# DOB
# State
# GenderCode
# RaceDesc
# MaritalDesc
# Performance Score
# Current Employee Rating
# Survey Date
# Engagement Score
# Satisfaction Score
# Work-Life Balance Score
# Training Date
# Training Program Name
# Training Type
# Training Outcome
# Training Duration(Days)
# Training Cost
# Age

# %%
df.head()
# Out:
#    Employee ID  StartDate                    Title BusinessUnit  \
# 0         3427  20-Sep-19  Production Technician I         CCDR
# 1         3428  11-Feb-23  Production Technician I           EW
# 2         3429  10-Dec-18       Area Sales Manager           PL
# 3         3430  21-Jun-21       Area Sales Manager         CCDR
# 4         3431  29-Jun-19       Area Sales Manager          TNS
#
#   EmployeeStatus EmployeeType PayZone EmployeeClassificationType  \
# 0         Active     Contract  Zone C                  Temporary
# 1         Active     Contract  Zone A                  Part-Time
# 2         Active    Full-Time  Zone B                  Part-Time
# 3         Active     Contract  Zone A                  Full-Time
# 4         Active     Contract  Zone A                  Temporary
#
#       DepartmentType              Division  ... Engagement Score  \
# 0  Production         Finance & Accounting  ...                1
# ...

# %%
df.columns.tolist()
# Out:
# ['Employee ID',
#  'StartDate',
#  'Title',
#  'BusinessUnit',
#  'EmployeeStatus',
#  'EmployeeType',
#  'PayZone',
#  'EmployeeClassificationType',
#  'DepartmentType',
#  'Division',
#  'DOB',
#  'State',
#  'GenderCode',
#  'RaceDesc',
#  'MaritalDesc',
#  'Performance Score',
#  'Current Employee Rating',
#  'Survey Date',
#  'Engagement Score',
#  'Satisfaction Score',
#  'Work-Life Balance Score',
#  'Training Date',
#  'Training Program Name',
#  'Training Type',
#  'Training Outcome',
#  'Training Duration(Days)',
#  'Training Cost',
#  'Age']

# %%
# Total Employees
print("Total Employees:", len(df))

# Department Wise Employees
print(df['DepartmentType'].value_counts())

# Gender Distribution
print(df['GenderCode'].value_counts())

# Performance Score
print(df['Performance Score'].value_counts())

# Training Outcome
print(df['Training Outcome'].value_counts())

# Average Satisfaction
print("Average Satisfaction:", df['Satisfaction Score'].mean())

# Average Engagement
print("Average Engagement:", df['Engagement Score'].mean())
# Out:
# Total Employees: 2845
# DepartmentType
# Production              1910
# IT/IS                    409
# Sales                    311
# Software Engineering     112
# Admin Offices             79
# Executive Office          24
# Name: count, dtype: int64
# GenderCode
# Female    1588
# Male      1257
# Name: count, dtype: int64
# Performance Score
# Fully Meets          2251
# Exceeds               346
# Needs Improvement     162
# PIP                    86
# Name: count, dtype: int64
# Training Outcome
# Completed     737
# Incomplete    731
# Passed        709
# Failed        668
# Name: count, dtype: int64
# Average Satisfaction: 3.0284710017574694
# Average Engagement: 2.941652021089631
